# %% [markdown]
# # Pandas  with datascience.Ai

# %%
import pandas as pd

# %% [markdown]
# # Read the database

# %%
movies = pd.read_csv(r"C:\Users\Satyabrata Sahoo\Desktop\naresh it\kiggle\workshop\feb3\movie.csv")

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.head(13) # to print top13 row
# Out:
#     movieId                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
# 5         6                         Heat (1995)
# 6         7                      Sabrina (1995)
# 7         8                 Tom and Huck (1995)
# 8         9                 Sudden Death (1995)
# 9        10                    GoldenEye (1995)
# 10       11      American President, The (1995)
# 11       12  Dracula: Dead and Loving It (1995)
# 12       13                        Balto (1995)
#
#                                          genres
# 0   Adventure|Animation|Children|Comedy|Fantasy
# 1                    Adventure|Children|Fantasy
# 2                                Comedy|Romance
# 3                          Comedy|Drama|Romance
# ...

# %%
ratings = pd.read_csv(r"C:\Users\Satyabrata Sahoo\Desktop\naresh it\kiggle\workshop\feb3\rating.csv")

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
tags = pd.read_csv(r"C:\Users\Satyabrata Sahoo\Desktop\naresh it\kiggle\workshop\feb3\tag.csv")

# %%
tags.shape
# Out:
# (465564, 4)

# %%
print(movies.shape) #return the shape
print(ratings.shape)
print(tags.shape)
# Out:
# (27278, 3)
# (20000263, 4)
# (465564, 4)

# %%
print(movies.columns)  # to show columns Attribute
print(ratings.columns)
print(tags.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
del ratings['timestamp'] # to delete
del tags['timestamp']

# %%
print(movies.columns)
print(ratings.columns)
print(tags.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')
# Index(['userId', 'movieId', 'rating'], dtype='object')
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.head() #bidefauklt print 5 rows
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %% [markdown]
# # Data structure
# # series

# %%
row_0 = tags.iloc[0] #return details of particular index
type(row_0)
# Out:
# pandas.core.series.Series

# %%
print(row_0)
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
row_0.index # return the column name/attribute of index 0
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
row_0['userId'] # information about userid in index 0
# Out:
# np.int64(18)

# %%
'rating' in row_0 # It checks whether 'rating' is a label in row_0.index
# Out:
# False

# %%
row_0.name
# Out:
# 0

# %%
row_0 = row_0.rename('firstRow')  #**doubt**
row_0.name
# Out:
# 'firstRow'

# %% [markdown]
# # DataFrame

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.index # return the range of row
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.iloc[ [0,11,500] ]  #to return particular row
# Out:
#      userId  movieId                tag
# 0        18     4141        Mark Waters
# 11       65     1783      noir thriller
# 500     342    55908  entirely dialogue

# %% [markdown]
# # Descriptive Statistics

# %%
ratings['rating'].describe() #return information Descriptive Statistics about ratings
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
# count	Number of non-null values
# mean	Average rating
# std	Standard deviation
# min	Lowest rating
# 25%	First quartile (Q1)
# 50%	Median
# 75%	Third quartile (Q3)
# max	Highest rating

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
ratings['rating'].mean()
# Out:
# np.float64(3.5255285642993797)

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
ratings['rating'].std()
# Out:
# 1.051988919275684

# %%
ratings['rating'].mode() # doubt
# Out:
# 0    4.0
# Name: rating, dtype: float64

# %%
ratings.corr() # function calculates the correlation matrix of the DataFrame
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
filter1 = ratings['rating'] > 10 # check conditional 
print(filter1)
filter1.any()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool
# np.False_

# %%
filter2 = ratings['rating'] > 0
filter2.all()
# Out:
# np.True_

# %% [markdown]
# # Data Cleaning: Handling Missing Data

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.isnull().any() # check if there is any null value in movie
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %% [markdown]
#  **single.any() return a series**

# %%
movies.isnull().any().any()
# Out:
# np.False_

# %% [markdown]
# **.any().any()- retrurn a single boolean**

# %%
ratings.shape
# Out:
# (20000263, 3)

# %%
ratings.isnull().any().any()
# Out:
# np.False_

# %%
tags.shape
# Out:
# (465564, 3)

# %%
tags.isnull().any().any()
# Out:
# np.True_

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
tags=tags.dropna() #method to remove/drop missing values (NaN) from your data./handle the missing value

# %%
tags.isnull().any().any()
# Out:
# np.False_

# %%
tags.shape
# Out:
# (465548, 3)

# %% [markdown]
# # Data visualization

# %%
# %matplotlib inline

ratings.hist(column='rating', figsize=(10,5))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
# hist is short for histogram, a type of plot in pandas (using matplotlib under the hood),whoshows the distribution of numerical data by grouping values into bins (intervals) and counting how many values fall into each bin.

# X-axis → value ranges (bins)

# Y-axis → frequency (count of values in each bin)

 # So, for your rating column, it shows how many ratings fall into each rating value.

# %%
ratings.boxplot(column='rating', figsize=(10,5))
# Out:
# <Axes: >

# %% [markdown]
# # Slicing out columns

# %%
tags['tag'].head()  #print the tag attribute column in tag dataframe table
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
movies[['title','genres']].head() # show two columns simulteniuosly of movie datframe
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[-10:] #returns the last 10 rows. # doubt
# Out:
#           userId  movieId  rating
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5

# %%
ratings.shape
# Out:
# (20000263, 3)

# %%
tag_counts = tags['tag'].value_counts()
tag_counts[-10:]
# Out:
# tag
# chiptunes         1
# ewan macgregor    1
# Disguises         1
# retarted          1
# operatic          1
# heartrending      1
# film crew         1
# es                1
# girltalk          1
# Spanish films     1
# Name: count, dtype: int64

# %%
tag_counts[:10].plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='tag'>
